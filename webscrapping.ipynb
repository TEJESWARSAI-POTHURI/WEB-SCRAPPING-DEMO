# %% [markdown]
# <a href="https://colab.research.google.com/github/TEJESWARSAI-POTHURI/WEB-SCRAPPING-DEMO/blob/main/webscrapping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from bs4 import BeautifulSoup
import requests

# %%
web_url = "https://www.tofler.in/companylist/hyderabad"
page = requests.get(web_url)

soup = BeautifulSoup(page.content, "html.parser")

soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head><meta content="IE=Edge" http-equiv="x-ua-compatible"/>
# <meta content="www.tofler.in" name="author"/>
# <meta content="Copyright (C)2015-2024 - Tofler" name="copyright">
# <meta content="global" name="distribution"/>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="all,index,follow" name="robots">
# <meta content="index,follow,archive" name="googlebot">
# <meta content="en_US" property="og:locale"/>
# <meta content="website" property="og:type"/>
# <meta content="Tofler" property="og:site_name"/>
# <meta content="https://www.tofler.in/images/svg/logo.svg" property="og:image"/>
# <meta content="255" property="og:image:width"/>
# <meta content="66" property="og:image:height"/>
# <meta content="https://www.tofler.in/companylist/hyderabad" property="og:url">
# <meta content="summary_large_image" name="twitter:card">
# <meta content="https://www.tofler.in/images/svg/logo.svg" name="twitter:image"/>
# <meta content="@twstofler" name="twitter:site"/>
# <link href="https://www.tofler.in/images/svg/logo.svg" rel="image_src"/>
# <link href="/images/logo_new" rel="icon"/>
# <title>Tofler | Search results</title>
# <link href="/favicon.ico" rel="icon" type="image/png"/>
# <link href="https://fonts.googleapis.com/css2?family=Open+Sans:ital,wght@0,300..800;1,300..800&amp;display=swap" rel="stylesheet"/>
# <link href="https://unpkg.com/leaflet/dist/leaflet.css" rel="stylesheet">
# <link href="//d1mgel6vch4ba4.cloudfront.net/assets/normalize.css" rel="stylesheet"/>
# <link href="//d1mgel6vch4ba4.cloudfront.net/assets/skeleton.css" rel="stylesheet"/>
# <link href="//d1mgel6vch4ba4.cloudfront.net/assets/bundle.prod.3.1.30.css" rel="stylesheet"/>
# <!--[if lt IE 9]>
#         <script src="/js/html5shiv.js"></script>
#         <script type='text/javascript' src="//cdnjs.cloudflare.com/ajax/libs/respond.js/1.4.2/respond.js"></script>
#         <![endif]-->
# <!-- Google Tag Manager -->
# <script>(function (w, d, s, l, i) {
#             w[l] = w[l] || []; w[l].push({
#                 'gtm.start':
#                     new Date().getTime(), event: 'gtm.js'
#             }); var f = d.getElementsByTagName(s)[0],
#                 j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : ''; j.async = true; j.src =
#                     'https://www.googletagmanager.com/gtm.js?id=' + i + dl; f.parentNode.insertBefore(j, f);
#         })(window, document, 'script', 'dataLayer', 'GTM-KVMX5VG');</script>
# <!-- End Google Tag Manager -->
# <!-- Google tag (gtag.js) -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-D30V7BL6HX"></script>
# <script>
#         window.dataLayer = window.dataLayer || [];
#         function gtag() { dataLayer.push(arguments); }
#         gtag('js', new Date());
#         gtag('config', 'G-D30V7BL6HX');
#     </script>
# <!-- End Google tag (gtag.js) -->
# </link></meta></meta></meta></meta></meta></head>
# <body class="relative min-h-screen"><section class="container nav_wrapper bg-white w-full top-0 left-0 justify-between flex items-center hide-on-print">
# <main class="row gap-0 w-full flex items-center">
# <nav class="twelve columns h-76 flex justify-between gap-12 items-center">
# <div class="flex items-center gap-16">
# <img alt="menu icon" class="mobile_only pointer menu_icon scale" src="/images/svg/menu.svg"/>
# <a href="/"><img alt="logo img" class="logo block" src="/images/svg/logo.svg"/></a>
# <div class="flex gap-40 home_screen_only_nav_item" style="display: none">
# <a class="text-dark text-base decoration-0 mobile-hide" href="/benefits">Benefits</a>
# <a class="text-dark text-base decoration-0 mobile-hide" href="/about">About us</a>
# </div>
# </div>
# <div class="text_input rounded-base mobile-hide relative" id="searchWrapper" style="margin-left: 16px; margin-right: auto;">
# <img alt="search icon" src="/images/svg/search-normal"/>
# <input id="searchbox" placeholder="Search company, CIN OR DIN" type="text"/>
# </div>
# <div class="flex items-center navbar_right_part_wrapper">
# <a class="text-dark text-base decoration-0 mobile-hide" href="/benefits" style="display: none">Benefits</a>
# <div class="text-dark text-base tools pointer mobile-hide relative">
# </div>
# <div class="flex gap-16 benefits_for_other_pages mobile-hide">
# <a class="text-dark text-base decoration-0 mobile-hide" href="/benefits">Benefits</a>
# </div>
# <div class="flex gap-16 home_screen_left_navbar mobile-hide">
# <a class="button" href="/price-and-plans">See Price &amp; Plans</a>
# </div>
# <img alt="search icon" class="mobile_only search_icon scale pointer" src="/images/svg/search-normal"/>
# <a class="relative" href="/viewcart" style="margin-top: 7px"><img alt="cart img" class="scale pointer" src="/images/svg/shopping-cart-primary.svg"/> <span class="absolute text-sm text-primary font-semibold flex justify-center items-center rounded" style="top: -8px; right : -8px; background-color: orange; color: black; height: 20px; width: 20px;">0</span></a>
# <div class="flex gap-16 home_screen_left_navbar">
# <a class="button bg-main text-white" href="/login">Login</a>
# </div>
# </div>
# </nav>
# </main>
# </section>
# <section class="mobile_nav bg-light">
# <main class="row bg-white">
# <div class="container">
# <nav class="twelve columns h-76 flex justify-between items-center">
# <div class="flex items-center gap-16">
# <img alt="cancel icon" class="close_icon pointer scale" src="/images/svg/cancel.svg"/>
# <a href="/"><img alt="logo icon" class="logo block" src="/images/svg/logo.svg"/></a>
# </div>
# <div class="flex items-center gap-16 mobile-hide">
# <div class="flex items-center gap-8">
# <img alt="user icon" class="rounded user_icon pointer" src="/images/icon-foreigner-avatar.png"/>
# </div>
# </div>
# </nav>
# </div>
# </main>
# <main class="container overflow-y-scroll flex-col gap-24 justify-between py-16 mx-auto page_screen p-0">
# <div class="flex-col gap-24 w-full">
# <div class="rounded-lg flex-col w-full bg-grey gap-1 shadow">
# <div class="p-12 bg-white flex-col gap-0 rounded-b text-dark">
# <a class="py-8 px-12 rounded-t text-base text-primary bg-white flex items-center gap-8" href="/benefits"><img alt="star icon" src="/images/svg/ranking.svg"/> Benefits</a>
# <a class="py-8 px-12 flex items-center gap-8 text-dark text-primary rounded-md" href="/dashboard" style="opacity: 0.8;"><img alt="menu icon" src="/images/svg/menu-info"/>Dashboard</a>
# </div>
# </div>
# <a class="button bg-light w-full py-10 px-12" href="/price-and-plans">See Price &amp; Plans</a>
# </div>
# <div class="flex-col gap-12 items-center">
# <!-- <a href="/logoff" class="button error border-error w-full py-10 px-12 mt-base flex items-center gap-8">
#         <img src="/images/svg/logout.svg" alt="logout icon"> Log out</a> -->
# <p class="text-sm-base">Not registered yet? Get a free account.</p>
# <a class="text-primary text-base font-semibold" href="/signup">Sign Up</a>
# </div>
# </main>
# </section>
# <section class="search_section bg-light">
# <main class="row">
# <div class="module relative" id="searchWrapperMobile" style="padding: 8px 12px !important; gap: 0 !important;">
# <img alt="search icon" src="/images/svg/search-normal"/>
# <input class="flex-1 text_input" id="searchboxMobile" placeholder="Search company, CIN OR DIN" type="text"/>
# <img alt="cancel icon" class="close_search pointer scale" src="/images/svg/close-circle.svg"/>
# </div>
# <!-- <div class="module"> -->
# <!-- <input type="text" autofocus placeholder="Search company, CIN OR DIN" class="text_input"> -->
# <ul class="px-16 flex-col gap-16">
# </ul>
# </main>
# </section>
# <!-- Hide navbar search in Home page script below -->
# <script>
#   document.addEventListener('DOMContentLoaded', () => {
#     const logo = document.querySelector('.logo');
#     const benefitsForOtherPages = document.querySelector('.benefits_for_other_pages');
#     const home_screen_only_nav_item = document.querySelector('.home_screen_only_nav_item');
#     const non_home_screen_nav_item = document.querySelector('.non_home_screen_nav_item');
#     const currentPage = window.location.pathname;
#
#     if (currentPage === '/') {
#       home_screen_only_nav_item.style.display = 'flex';
#       logo.style.display = 'none';
#       benefitsForOtherPages.style.display = 'none';
#     } else {
#       non_home_screen_nav_item.style.display = 'flex';
#       benefitsForOtherPages.style.display = 'flex';
#     }
#   });
#
# </script>
# <!-- Navbar toggle script below for moble screens only -->
# <script>
#
#   document.addEventListener('DOMContentLoaded', () => {
#     const toggleSections = (trigger, section, close) => {
#       const triggerElement = document.querySelector(trigger);
#       const sectionElement = document.querySelector(section);
#       const closeElement = document.querySelector(close);
#
#       triggerElement.addEventListener('click', () => {
#         sectionElement.style.display = 'block';
#         document.body.classList.add('no-scroll');
#       });
#
#       closeElement.addEventListener('click', () => {
#         sectionElement.style.display = 'none';
#         document.body.classList.remove('no-scroll');
#       });
#     };
#
#     toggleSections('.menu_icon', '.mobile_nav', '.close_icon');
#     toggleSections('.search_icon', '.search_section', '.close_search');
#   });
#
#
#
#
# </script>
# <!-- Search bar focus view and hide on focus lose script below -->
# <script>
#   document.addEventListener('DOMContentLoaded', () => {
#   const searchInput = document.getElementById('searchbox');
#   const searchSuggestionBox = document.querySelector('.search_suggestion_box');
#
#   searchInput.addEventListener('focus', () => {
#     searchSuggestionBox.style.display = 'flex';
#   });
#
#   searchInput.addEventListener('blur', () => {
#     setTimeout(() => {
#       searchSuggestionBox.style.display = 'none';
#     }, 100); // Adding a small delay to allow clicks on suggestions
#   });
# });
# </script>
# <section class="flex-col gap-32">
# <main class="py-24 px-40 container shadow-lg flex-1 bg-white rounded-lg flex-col gap-24 my-32">
# <h1 class="text-24 font-semibold text-grey-600 flex items-center gap-8">
# <span class="text-dark">Browse the list of all Indian companies</span>
# </h1>
# <div class="table_wrapper mobile-hide" style="min-height: 440px; overflow-y: auto;">
# <table class="responsive-table collapse overflow-x-scroll nowrap w-full" id="data-table">
# <thead>
# <tr class="bg-light text-left">
# <th>Business Name
#                     </th>
# <th>
# <p class="flex gap-8 items-center">
#                             Incorp. Year
#                             <img alt="filter" class="scale pointer" id="sort-icon-0" src="/images/svg/sort-filter.svg"/>
# </p>
# </th>
# <th>
# <p class="flex gap-8 items-center">
#                             Industry
#                             <img alt="filter" class="scale pointer" id="sort-icon-1" src="/images/svg/sort-filter.svg"/>
# </p>
# </th>
# <th>
# <p class="flex gap-8 items-center">
#                             Status
#                             <img alt="filter" class="scale pointer" id="sort-icon-2" src="/images/svg/sort-filter.svg"/>
# </p>
# </th>
# </tr>
# </thead>
# <tbody id="table-body">
# <tr>
# <td><a href="/omega-ag-seeds-punjab-limited/company/L01119TG1992PLC082816">OMEGA AG SEEDS PUNJAB LIMITED</a></td>
# <td>1992</td>
# <td></td>
# <td>Active</td>
# </tr>
# <tr>
# <td><a href="/classic-mushrooms-limited/company/L01120AP1996PLC023949">CLASSIC MUSHROOMS LIMITED</a></td>
# <td>1996</td>
# <td></td>
# <td>Active</td>
# </tr>
# <tr>
# <td><a href="/neha-international-limited/company/L01122TG1993PLC015987">NEHA INTERNATIONAL LIMITED</a></td>
# <td>1993</td>
# <td></td>
# <td>Active</td>
# </tr>
# <tr>
# <td><a href="/southern-petrochemical-industries-corporation-limited/company/L11101TN1969PLC005778">SOUTHERN PETROCHEMICAL INDUSTRIES CORPORATION LIMITED</a></td>
# <td>1969</td>
# <td></td>
# <td>Active</td>
# </tr>
# <tr>
# <td><a href="/nmdc-limited/company/L13100TG1958GOI001674">NMDC LIMITED</a></td>
# <td>1958</td>
# <td></td>
# <td>Active</td>
# </tr>
# <tr>
# <td><a href="/vertical-industries-limited/company/L14102TG1990PLC011398">VERTICAL INDUSTRIES LIMITED</a></td>
# <td>1990</td>
# <td></td>
# <td>Active</td>
# </tr>
# <tr>
# <td><a href="/mishra-dhatu-nigam-limited/company/L14292TG1973GOI001660">MISHRA DHATU NIGAM LIMITED</a></td>
# <td>1973</td>
# <td></td>
# <td>Active</td>
# </tr>
# <tr>
# <td><a href="/heritage-foods-limited/company/L15209TG1992PLC014332">HERITAGE FOODS LIMITED</a></td>
# <td>1992</td>
# <td></td>
# <td>Active</td>
# </tr>
# <tr>
# <td><a href="/kapston-services-limited/company/L15400TG2009PLC062658">KAPSTON SERVICES LIMITED</a></td>
# <td>2009</td>
# <td></td>
# <td>Active</td>
# </tr>
# <tr>
# <td><a href="/gayatri-sugars-limited/company/L15421TG1995PLC020720">GAYATRI SUGARS LIMITED</a></td>
# <td>1995</td>
# <td></td>
# <td>Active</td>
# </tr>
# <tr>
# <td><a href="/tanvi-foods-india-limited/company/L15433TG2007PLC053406">TANVI FOODS (INDIA) LIMITED</a></td>
# <td>2007</td>
# <td></td>
# <td>Active</td>
# </tr>
# <tr>
# <td><a href="/sampre-nutritions-limited/company/L15499TG1991PLC013515">SAMPRE NUTRITIONS LIMITED</a></td>
# <td>1991</td>
# <td></td>
# <td>Active</td>
# </tr>
# <tr>
# <td><a href="/sanghi-polyesters-limited/company/L17110AP1986PLC009021">SANGHI POLYESTERS LIMITED</a></td>
# <td>1986</td>
# <td></td>
# <td>Active</td>
# </tr>
# <tr>
# <td><a href="/golden-carpets-ltd/company/L17220TG1993PLC016672">GOLDEN CARPETS LTD</a></td>
# <td>1993</td>
# <td></td>
# <td>Active</td>
# </tr>
# <tr>
# <td><a href="/samrat-spinners-limited/company/L18100TG1981PLC003199">SAMRAT SPINNERS LIMITED</a></td>
# <td>1981</td>
# <td></td>
# <td>Active</td>
# </tr>
# <tr>
# <td><a href="/terrygold-india-ltd/company/L18100TG1991PLC013446">TERRYGOLD (INDIA) LTD</a></td>
# <td>1991</td>
# <td></td>
# <td>Active</td>
# </tr>
# <tr>
# <td><a href="/gold-won-textiles-ltd/company/L18100TG1993PLC015718">GOLD WON TEXTILES LTD.</a></td>
# <td>1993</td>
# <td></td>
# <td>Active</td>
# </tr>
# <tr>
# <td><a href="/nutricircle-limited/company/L18100TG1993PLC015901">NUTRICIRCLE LIMITED</a></td>
# <td>1993</td>
# <td></td>
# <td>Active</td>
# </tr>
# <tr>
# <td><a href="/gtn-industries-limited/company/L18101TG1962PLC054323">GTN INDUSTRIES LIMITED</a></td>
# <td>1962</td>
# <td></td>
# <td>Active</td>
# </tr>
# <tr>
# <td><a href="/tamilnadu-newsprint-and-papers-limited/company/L22121TN1979PLC007799">TAMILNADU NEWSPRINT &amp; PAPERS LIMITED</a></td>
# <td>1979</td>
# <td></td>
# <td>Active</td>
# </tr>
# <tr>
# <td><a href="/mps-limited/company/L22122TN1970PLC005795">MPS LIMITED</a></td>
# <td>1970</td>
# <td></td>
# <td>Active</td>
# </tr>
# <tr>
# <td><a href="/gayatri-bioorganics-limited/company/L24110TG1991PLC013512">GAYATRI BIOORGANICS LIMITED</a></td>
# <td>1991</td>
# <td></td>
# <td>Active</td>
# </tr>
# <tr>
# <td><a href="/tuticorin-alkali-chemicals-and-fertilizers-limited/company/L24119TN1971PLC006083">TUTICORIN ALKALI CHEMICALS AND FERTILIZERS LIMITED</a></td>
# <td>1971</td>
# <td></td>
# <td>Active</td>
# </tr>
# <tr>
# <td><a href="/deccan-polypacks-limited/company/L24134TG1984PLC005215">DECCAN POLYPACKS LIMITED</a></td>
# <td>1984</td>
# <td></td>
# <td>Active</td>
# </tr>
# <tr>
# <td><a href="/nacl-industries-limited/company/L24219TG1986PLC016607">NACL INDUSTRIES LIMITED</a></td>
# <td>1986</td>
# <td></td>
# <td>Active</td>
# </tr>
# <tr>
# <td><a href="/venmax-drugs-and-pharmaceuticals-limited/company/L24230TG1988PLC009102">VENMAX DRUGS AND PHARMACEUTICALS LIMITED</a></td>
# <td>1988</td>
# <td></td>
# <td>Active</td>
# </tr>
# <tr>
# <td><a href="/lordvin-labs-ltd/company/L24230TG1994PLC017377">LORDVIN LABS LTD</a></td>
# <td>1994</td>
# <td></td>
# <td>Active</td>
# </tr>
# <tr>
# <td><a href="/parasai-mercantile-limited/company/L24231TG1995PLC019582">PARASAI MERCANTILE LIMITED</a></td>
# <td>1995</td>
# <td></td>
# <td>Active</td>
# </tr>
# <tr>
# <td><a href="/retina-paints-limited/company/L24232TG2010PLC071018">RETINA PAINTS LIMITED</a></td>
# <td>2010</td>
# <td></td>
# <td>Active</td>
# </tr>
# <tr>
# <td><a href="/saamya-biotech-india-limited/company/L24239AP2002PLC039449">SAAMYA BIOTECH (INDIA) LIMITED</a></td>
# <td>2002</td>
# <td></td>
# <td>Active</td>
# </tr>
# </tbody>
# </table>
# </div>
# <div class="pagination select-none flex items-center text-sm-base justify-end gap-16 overflow-auto mobile-hide">
# <button class="btn flex p-0 border-none gap-6 justify-center items-center text-sm-base" disabled="" id="prev-btn" onclick="prevPage()">
# <img alt="left arrow" src="/images/svg/arrow-left.svg"/>
#             Back
#         </button>
# <span id="page-numbers"></span>
# <button class="btn flex p-0 border-none gap-6 justify-center items-center text-sm-base" id="next-btn" onclick="nextPage()">
#             Next
#             <img alt="right arrow" src="/images/svg/arrow-right.svg"/>
# </button>
# </div>
# <p class="mobile-hide">*Industry classification is inferred. If the company has changed line of business without
#         intimating the
#         Registrar or is a diversified business, classification may be incorrect. In general, we make no warranties about
#         accuracy of industry classification.
#     </p>
# <!-- SEARCH RESULTS FOR MOBILE SCREEN ONLY BELOW -->
# </main>
# <main class="bg-base py-24">
# <div class="container mx-auto row">
# <div class="twelve columns">
# <span class="text">
#                 Tofler, TWS Systems Private Limited and its officers respect the Intellectual Property Rights of all
#                 people. Tofler makes no claim of ownership or affiliation with any trademark (REGISTERED OR
#                 UNREGISTERED) that forms part of any Company/LLP name listed on this page. Trademarks, if any,
#                 listed on
#                 this page belong to...
#             </span><a class="font-semibold text-primary underline-none nowrap" href="/disclaimer" target="_blank">Read
#                 More</a>
# </div>
# </div>
# </main>
# <script>
#     let currentPage = 1;
#     const rowsPerPage = 10;
#     const tableBody = document.getElementById('table-body');
#     const rows = Array.from(tableBody.getElementsByTagName('tr'));
#     let sortedRows = [...rows];
#     const totalPages = Math.ceil(rows.length / rowsPerPage);
#     let currentSortColumn = null;
#     let sortDirection = 'none'; // 'asc', 'desc', 'none'
#
#     function displayRows() {
#         tableBody.innerHTML = "";
#         const start = (currentPage - 1) * rowsPerPage;
#         const end = start + rowsPerPage;
#         const paginatedRows = sortedRows.slice(start, end);
#
#         paginatedRows.forEach(row => {
#             tableBody.appendChild(row);
#         });
#
#         document.getElementById('prev-btn').disabled = currentPage === 1;
#         document.getElementById('next-btn').disabled = currentPage === totalPages;
#         document.getElementById('page-numbers').innerText = `Page ${currentPage} of ${totalPages}`;
#     }
#
#     function sortTable(columnIndex) {
#         const sortIcon = document.getElementById(`sort-icon-${columnIndex}`);
#
#         if (currentSortColumn === columnIndex) {
#             if (sortDirection === 'asc') {
#                 sortDirection = 'desc';
#                 sortIcon.src = '/images/svg/sort-filter.svg';
#             } else if (sortDirection === 'desc') {
#                 sortDirection = 'none';
#                 sortIcon.src = '/images/svg/sort-filter.svg';
#             } else {
#                 sortDirection = 'asc';
#                 sortIcon.src = '/images/svg/sort-filter.svg';
#             }
#         } else {
#             // Reset all icons to default
#             for (let i = 0; i < 3; i++) {
#                 document.getElementById(`sort-icon-${i}`).src = '/images/svg/sort-filter.svg';
#             }
#             currentSortColumn = columnIndex;
#             sortDirection = 'asc';
#             sortIcon.src = '/images/svg/sort-filter.svg';
#         }
#
#         if (sortDirection === 'none') {
#             sortedRows = [...rows]; // Reset to original order
#         } else {
#             sortedRows.sort((a, b) => {
#                 const aText = a.children[columnIndex].textContent.trim();
#                 const bText = b.children[columnIndex].textContent.trim();
#
#                 if (sortDirection === 'asc') {
#                     return aText.localeCompare(bText, undefined, { numeric: true });
#                 } else {
#                     return bText.localeCompare(aText, undefined, { numeric: true });
#                 }
#             });
#         }
#
#         currentPage = 1; // Reset to first page after sorting
#         displayRows();
#     }
#
#     function nextPage() {
#         if (currentPage < totalPages) {
#             currentPage++;
#             displayRows();
#         }
#     }
#
#     function prevPage() {
#         if (currentPage > 1) {
#             currentPage--;
#             displayRows();
#         }
#     }
#
#     // Attach sort event listeners to the filter icons
#     document.querySelectorAll('th p img').forEach((icon, index) => {
#         icon.addEventListener('click', () => sortTable(index));
#     });
#
#     // Initialize the table with the first page of rows
#     displayRows();
#
# </script>
# <!-- Get search query from home page script below -->
# <script>
#     $(document).ready(function () {
#         // Retrieve query parameter from URL
#         const urlParams = new URLSearchParams(window.location.search);
#         const query = urlParams.get('q');
#         console.log(query)
#
#         // Display the query in an element if needed
#         if (query) {
#             $(".search-results-title").text(`Search Results for "${query}"`);
#         }
#     });
# </script>
# </section>
# <!-- BottomBanner -->
# <footer class="footer_wrapper py-40 flex-col gap-80 hide-on-print">
# <div class="container text-white">
# <div class="footer_container">
# <div class="flex-col gap-32">
# <img alt="logo img" class="logo" src="/images/svg/logo_light.svg"/>
# <p class="text-sm-base font-light footer_desc">All trademarks, service marks, trade names and logos appearing on the site
#           are the property of their
#           respective owners.</p>
# <div class="flex-col gap-4 font-regular">
# <p>Need any help? Email us at:</p>
# <p>support@tofler.in</p>
# </div>
# </div>
# <div class="flex gap-100 justify-between">
# <div class="flex-col gap-24">
# <h3 class="text-white text-md">QUICK LINKS</h3>
# <ul class="flex-col gap-8 font-light text-sm">
# <li><a class="text-base" href="/about">About us</a></li>
# <li><a class="text-base" href="/blog">Blogs</a></li>
# </ul>
# </div>
# <div class="flex-col gap-24">
# <h3 class="text-white text-md">LEGAL</h3>
# <ul class="flex-col gap-8 font-light text-sm">
# <li><a class="text-base" href="/tos">Terms</a></li>
# <li><a class="text-base" href="/privacy">Privacy</a></li>
# <li><a class="text-base" href="/disclaimer">Disclaimer</a></li>
# </ul>
# </div>
# </div>
# <div class="flex-col gap-32">
# <div class="font-normal flex-col gap-2">
# <p class="">TWS Systems Private Limited (Tofler)</p>
# <p class="">Gurgaon, Haryana - 122002</p>
# <p class="">(CIN: U72502DL2013PTC261372)</p>
# </div>
# <div class="flex-col gap-24">
# <h3 class="text-white text-md">FOLLOW US ON:</h3>
# <div class="flex gap-24">
# <a href="https://www.facebook.com/twstofler" target="_blank"> <img alt="social media icon" src="/images/svg/fb.svg"/></a>
# <a href="https://www.linkedin.com/company/tofler/" target="_blank"> <img alt="social media icon" src="/images/svg/linkedin.svg"/></a>
# <a href="https://x.com/twstofler" target="_blank"> <img alt="social media icon" src="/images/svg/twitter.svg"/></a>
# <a href="https://www.youtube.com/@tofler8107" target="_blank"> <img alt="social media icon" src="/images/svg/youtube.svg"/></a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="container flex gap-10 text-dark rounded-base justify-between items-center bg-white py-16 low_footer text-sm-base">
# <p>© TWS Systems Private Limited.</p>
# <p>All Rights Reserved.</p>
# </div>
# </footer>
# <script src="/js/jquery-2.1.4.min.js"></script>
# <script src="/js/jquery-ui.min.js"></script>
# <script src="//d1mgel6vch4ba4.cloudfront.net/assets/bundle.prod.3.1.30.js"></script>
# <!-- Google Tag Manager (noscript) -->
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-KVMX5VG" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) -->
# </body>
# </html>

# %%
find = soup.find_all('table',class_="responsive-table")

# %%
tableheading = soup.find_all('th')

tableheading
# Out:
# [<th>Business Name
#                      </th>,
#  <th>
#  <p class="flex gap-8 items-center">
#                              Incorp. Year
#                              <img alt="filter" class="scale pointer" id="sort-icon-0" src="/images/svg/sort-filter.svg"/>
#  </p>
#  </th>,
#  <th>
#  <p class="flex gap-8 items-center">
#                              Industry
#                              <img alt="filter" class="scale pointer" id="sort-icon-1" src="/images/svg/sort-filter.svg"/>
#  </p>
#  </th>,
#  <th>
#  <p class="flex gap-8 items-center">
#                              Status
#                              <img alt="filter" class="scale pointer" id="sort-icon-2" src="/images/svg/sort-filter.svg"/>
#  </p>
#  </th>]

# %%
names = [titles.text.strip() for titles in tableheading]

names
# Out:
# ['Business Name', 'Incorp. Year', 'Industry', 'Status']

# %%
import pandas as pd

df = pd.DataFrame(columns = names)

df
# Out:
# Empty DataFrame
# Columns: [Business Name, Incorp. Year, Industry, Status]
# Index: []

# %%
for rows in find:
    rows = rows.find_all('tr')
    for row in rows[1:]:
        data = row.find_all('td')
        rowdata = [row.text.strip() for row in data]
        print(rowdata)

        length = len(df)
        df.loc[length] = rowdata
# Out:
# ['OMEGA AG SEEDS PUNJAB LIMITED', '1992', '', 'Active']
# ['CLASSIC MUSHROOMS LIMITED', '1996', '', 'Active']
# ['NEHA INTERNATIONAL LIMITED', '1993', '', 'Active']
# ['SOUTHERN PETROCHEMICAL INDUSTRIES CORPORATION LIMITED', '1969', '', 'Active']
# ['NMDC LIMITED', '1958', '', 'Active']
# ['VERTICAL INDUSTRIES LIMITED', '1990', '', 'Active']
# ['MISHRA DHATU NIGAM LIMITED', '1973', '', 'Active']
# ['HERITAGE FOODS LIMITED', '1992', '', 'Active']
# ['KAPSTON SERVICES LIMITED', '2009', '', 'Active']
# ['GAYATRI SUGARS LIMITED', '1995', '', 'Active']
# ['TANVI FOODS (INDIA) LIMITED', '2007', '', 'Active']
# ['SAMPRE NUTRITIONS LIMITED', '1991', '', 'Active']
# ['SANGHI POLYESTERS LIMITED', '1986', '', 'Active']
# ['GOLDEN CARPETS LTD', '1993', '', 'Active']
# ['SAMRAT SPINNERS LIMITED', '1981', '', 'Active']
# ['TERRYGOLD (INDIA) LTD', '1991', '', 'Active']
# ['GOLD WON TEXTILES LTD.', '1993', '', 'Active']
# ['NUTRICIRCLE LIMITED', '1993', '', 'Active']
# ['GTN INDUSTRIES LIMITED', '1962', '', 'Active']
# ['TAMILNADU NEWSPRINT & PAPERS LIMITED', '1979', '', 'Active']
# ['MPS LIMITED', '1970', '', 'Active']
# ['GAYATRI BIOORGANICS LIMITED', '1991', '', 'Active']
# ['TUTICORIN ALKALI CHEMICALS AND FERTILIZERS LIMITED', '1971', '', 'Active']
# ['DECCAN POLYPACKS LIMITED', '1984', '', 'Active']
# ['NACL INDUSTRIES LIMITED', '1986', '', 'Active']
# ['VENMAX DRUGS AND PHARMACEUTICALS LIMITED', '1988', '', 'Active']
# ['LORDVIN LABS LTD', '1994', '', 'Active']
# ['PARASAI MERCANTILE LIMITED', '1995', '', 'Active']
# ['RETINA PAINTS LIMITED', '2010', '', 'Active']
# ['SAAMYA BIOTECH (INDIA) LIMITED', '2002', '', 'Active']

# %%
df
# Out:
#                                         Business Name Incorp. Year Industry  \
# 0                       OMEGA AG SEEDS PUNJAB LIMITED         1992
# 1                           CLASSIC MUSHROOMS LIMITED         1996
# 2                          NEHA INTERNATIONAL LIMITED         1993
# 3   SOUTHERN PETROCHEMICAL INDUSTRIES CORPORATION ...         1969
# 4                                        NMDC LIMITED         1958
# 5                         VERTICAL INDUSTRIES LIMITED         1990
# 6                          MISHRA DHATU NIGAM LIMITED         1973
# 7                              HERITAGE FOODS LIMITED         1992
# 8                            KAPSTON SERVICES LIMITED         2009
# 9                              GAYATRI SUGARS LIMITED         1995
# 10                        TANVI FOODS (INDIA) LIMITED         2007
# 11                          SAMPRE NUTRITIONS LIMITED         1991
# 12                          SANGHI POLYESTERS LIMITED         1986
# 13                                 GOLDEN CARPETS LTD         1993
# 14                            SAMRAT SPINNERS LIMITED         1981
# 15                              TERRYGOLD (INDIA) LTD         1991
# 16                             GOLD WON TEXTILES LTD.         1993
# 17                                NUTRICIRCLE LIMITED         1993
# 18                             GTN INDUSTRIES LIMITED         1962
# 19               TAMILNADU NEWSPRINT & PAPERS LIMITED         1979
# 20                                        MPS LIMITED         1970
# 21                        GAYATRI BIOORGANICS LIMITED         1991
# 22  TUTICORIN ALKALI CHEMICALS AND FERTILIZERS LIM...         1971
# 23                           DECCAN POLYPACKS LIMITED         1984
# 24                            NACL INDUSTRIES LIMITED         1986
# 25           VENMAX DRUGS AND PHARMACEUTICALS LIMITED         1988
# 26                                   LORDVIN LABS LTD         1994
# 27                         PARASAI MERCANTILE LIMITED         1995
# 28                              RETINA PAINTS LIMITED         2010
# 29                     SAAMYA BIOTECH (INDIA) LIMITED         2002
#
#     Status
# 0   Active
# 1   Active
# 2   Active
# 3   Active
# 4   Active
# 5   Active
# 6   Active
# 7   Active
# 8   Active
# 9   Active
# 10  Active
# 11  Active
# 12  Active
# 13  Active
# 14  Active
# 15  Active
# 16  Active
# 17  Active
# 18  Active
# 19  Active
# 20  Active
# 21  Active
# 22  Active
# 23  Active
# 24  Active
# 25  Active
# 26  Active
# 27  Active
# 28  Active
# 29  Active

# %%
# prompt: Using dataframe df: bargraph

import pandas as pd
import matplotlib.pyplot as plt

# Assuming 'df' is your DataFrame
# Convert 'Incorp. Year' to numeric, handling potential errors
df['Incorp. Year'] = pd.to_numeric(df['Incorp. Year'], errors='coerce')

# Group by 'Incorp. Year' and count the number of companies
year_counts = df.groupby('Incorp. Year').size().reset_index(name='Company Count')

# Create the bar plot
plt.figure(figsize=(12, 6))  # Adjust figure size as needed
plt.bar(year_counts['Incorp. Year'], year_counts['Company Count'], color='skyblue')
plt.xlabel('Incorporation Year')
plt.ylabel('Number of Companies')
plt.title('Number of Companies Incorporated Each Year')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout to prevent labels from overlapping
plt.show()

# %%
df.to_csv(r'C:\Users\TEJESWARSAI\Documents\webscrapper.csv')

# %%
df
# Out:
#                                         Business Name Incorp. Year Industry  \
# 0                       OMEGA AG SEEDS PUNJAB LIMITED         1992
# 1                           CLASSIC MUSHROOMS LIMITED         1996
# 2                          NEHA INTERNATIONAL LIMITED         1993
# 3   SOUTHERN PETROCHEMICAL INDUSTRIES CORPORATION ...         1969
# 4                                        NMDC LIMITED         1958
# 5                         VERTICAL INDUSTRIES LIMITED         1990
# 6                          MISHRA DHATU NIGAM LIMITED         1973
# 7                              HERITAGE FOODS LIMITED         1992
# 8                            KAPSTON SERVICES LIMITED         2009
# 9                              GAYATRI SUGARS LIMITED         1995
# 10                        TANVI FOODS (INDIA) LIMITED         2007
# 11                          SAMPRE NUTRITIONS LIMITED         1991
# 12                          SANGHI POLYESTERS LIMITED         1986
# 13                                 GOLDEN CARPETS LTD         1993
# 14                            SAMRAT SPINNERS LIMITED         1981
# 15                              TERRYGOLD (INDIA) LTD         1991
# 16                             GOLD WON TEXTILES LTD.         1993
# 17                                NUTRICIRCLE LIMITED         1993
# 18                             GTN INDUSTRIES LIMITED         1962
# 19               TAMILNADU NEWSPRINT & PAPERS LIMITED         1979
# 20                                        MPS LIMITED         1970
# 21                        GAYATRI BIOORGANICS LIMITED         1991
# 22  TUTICORIN ALKALI CHEMICALS AND FERTILIZERS LIM...         1971
# 23                           DECCAN POLYPACKS LIMITED         1984
# 24                            NACL INDUSTRIES LIMITED         1986
# 25           VENMAX DRUGS AND PHARMACEUTICALS LIMITED         1988
# 26                                   LORDVIN LABS LTD         1994
# 27                         PARASAI MERCANTILE LIMITED         1995
# 28                              RETINA PAINTS LIMITED         2010
# 29                     SAAMYA BIOTECH (INDIA) LIMITED         2002
#
#     Status
# 0   Active
# 1   Active
# 2   Active
# 3   Active
# 4   Active
# 5   Active
# 6   Active
# 7   Active
# 8   Active
# 9   Active
# 10  Active
# 11  Active
# 12  Active
# 13  Active
# 14  Active
# 15  Active
# 16  Active
# 17  Active
# 18  Active
# 19  Active
# 20  Active
# 21  Active
# 22  Active
# 23  Active
# 24  Active
# 25  Active
# 26  Active
# 27  Active
# 28  Active
# 29  Active
